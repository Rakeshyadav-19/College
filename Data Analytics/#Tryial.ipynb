# %%
import random
ran = random.randint(0, 1024)
print(ran)
# Out:
# 340

# %%
import pandas as pd

dat = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris.csv")

dat
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import numpy as np
arr0 = np.array([5,3,8,9,4,3,6,9])
print(arr0)

print(np.__version__)

print(f"The type of arr is {type(arr0)}")

arr1 = np.array((5))
print(arr1.ndim)

arr2 = np.array([1, 2, 3, 4, 5])
print(arr2.ndim)

arr3 = np.array([[1, 2, 3], [4, 5, 6]])
print(arr3.ndim)

arr4 = np.array([[[1, 2, 3], [4, 5, 6]], [[1, 2, 3], [4, 5, 6]]])
print(arr4.ndim)

# to create an array of n dimension
arr5 = np.array([1, 2, 3, 4], ndmin=5)
print(arr5.ndim)


# Accesing elements of array
print(arr0[0])

print('2nd element on 1st row: ', arr3[0, 1])
# Out:
# [5 3 8 9 4 3 6 9]
# 1.25.2
# The type of arr is <class 'numpy.ndarray'>
# 0
# 1
# 2
# 3
# 5
# 5
# 2nd element on 1st row:  2
